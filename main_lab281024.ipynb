# %% [markdown]
# # Antes de empezar :
#    - Estos ejercicios están relacionados con las lecciones Subconjunto y Estadísticas descriptivas.
#    - Tenga en cuenta que necesitará utilizar algunas de las funciones que aprendió en las lecciones anteriores.
#    - Todos los conjuntos de datos se proporcionan en la carpeta `your-code` de este laboratorio.
#    - Elabora tus códigos y resultados tanto como puedas.
#    - Esfuérzate al máximo para responder a las preguntas y completar las tareas y, sobre todo, ¡¡¡disfruta del proceso!!!

# %% [markdown]
# #### Importa todas las librerías necesarias

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Desafío 1

# %% [markdown]
# #### En este reto utilizaremos el archivo `Temp_States.csv`.
#
# #### Primero impórtalo en un marco de datos llamado `temp`.

# %%
df_temp = pd.read_csv(r"C:\Users\Flor Guindo\Documents\CURSO DATA ANALYTICS\Temp_States.csv")

# %% [markdown]
# #### Print `temp`

# %%
display(df_temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore los tipos de datos del marco de datos Temp. ¿Qué tipo de datos tenemos? Comenta tu resultado.

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 300.0+ bytes

# %%
# Hay strings para las columnas 'City' y 'State' y decimales para la columna 'Temperature'

# %% [markdown]
# #### Selecciona las filas en las que el estado es New York

# %%
State_NY = df_temp[df_temp['State'] == 'New York']

display(State_NY)
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### ¿Cuál es la temperatura media de las ciudades de Nueva York?

# %%
t_media_NY = State_NY['Temperature'].mean()
t_media_NY
# Out:
# 10.74074074074074

# %% [markdown]
# #### Queremos conocer las ciudades y estados con temperaturas superiores a 15 grados centígrados.

# %%
calidos = df_temp[df_temp['Temperature'] > 15][['City', 'State', 'Temperature']]
calidos
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Ahora, devuelva sólo las ciudades que tengan una temperatura superior a 15 grados centígrados.

# %%
calidos2 = df_temp[df_temp['Temperature'] > 15][['City','Temperature']]
calidos2
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### Queremos saber qué ciudades tienen una temperatura superior a 15 grados Celcius e inferior a 20 grados Celcius
#
# *Pista: Primero escriba la condición y luego seleccione las filas.

# %%
temp_medias = (df_temp['Temperature'] > 15) & (df_temp['Temperature'] < 20)
ciudades_filtradas = df_temp[temp_medias][['City','Temperature']]
display(ciudades_filtradas)
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222

# %%
df_temp['State'].value_counts()
# Out:
# State
# New York       3
# Connecticut    2
# New Jersey     2
# Name: count, dtype: int64

# %% [markdown]
# #### Halla la media y la desviación estándar de la temperatura de cada estado.
#
# *Pista: Utiliza las funciones de la lección Manipulación de datos*.

# %%
media_estados = df_temp[["Temperature", "State"]].groupby("State").mean()
print(f'La temperatura media de los estados es:')
display(media_estados)
# Out:
# La temperatura media de los estados es:
#              Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741

# %%
desviacion_estados = df_temp[["Temperature", "State"]].groupby("State").std()
print(f'La desviacion estandar de la temperatura por estados es:')
display(desviacion_estados)
# Out:
# La desviacion estandar de la temperatura por estados es:
#              Temperature
# State
# Connecticut     1.964186
# New Jersey      1.571348
# New York        8.133404

# %% [markdown]
# # Desafío 2

# %% [markdown]
# #### Cargar el fichero `employee.csv` en un DataFrame. Llama al dataframe `employee`.

# %%
employee = pd.read_csv(r"C:\Users\Flor Guindo\Documents\CURSO DATA ANALYTICS\Employee.csv")
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore los tipos de datos del marco de datos Temp. Comenta tus resultados

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 636.0+ bytes

# %% [markdown]
# #### Muestre visualmente la distribución de frecuencias (histograma) del conjunto de datos de empleados. Describa en pocas palabras estos histogramas.

# %%
sns.histplot(data=employee, x='Salary',hue= 'Title',bins=10)
plt.title('Histograma de Salarios por Titulo')
plt.xlabel('Salarios')
plt.ylabel('Frecuencia')
plt.show()

# %%
sns.histplot(data=employee, x='Gender',bins=10)
plt.title('Histograma de Salarios')
plt.xlabel('Salarios')
plt.ylabel('Frecuencia')
plt.show()

# %%
sns.histplot(data=employee, x='Years',bins=10)
plt.title('Histograma Antiguedad de empleados')
plt.xlabel('Años')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### ¿Cuál es el salario medio en esta empresa?

# %%
salario_medio = employee['Salary'].mean().round(2)
print(f'El salario medio en esta empresa es de: {salario_medio}')
# Out:
# El salario medio en esta empresa es de: 48.89

# %% [markdown]
# #### ¿Cuál es el salario más alto?

# %%
salario_max = employee['Salary'].max()
print(f'El salario máximo en esta empresa es de: {salario_max}')
# Out:
# El salario máximo en esta empresa es de: 70

# %% [markdown]
# #### ¿Cuál es el salario más bajo?

# %%
salario_min = employee['Salary'].min()
print(f'El salario minimo en esta empresa es de: {salario_min}')
# Out:
# El salario minimo en esta empresa es de: 30

# %% [markdown]
# #### ¿Quiénes son los empleados con el salario más bajo?

# %%
employee_filt = employee[employee['Salary'] == salario_min][['Name', 'Salary']]
display(employee_filt)
# Out:
#     Name  Salary
# 1  Maria      30
# 2  David      30

# %% [markdown]
# #### ¿Podría darnos toda la información sobre un empleado llamado David?

# %%
David = employee[employee['Name'] == 'David']
David
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### ¿Podría dar sólo el sueldo de David?

# %%
Sueldo_David = employee.loc[employee['Name'] == 'David', 'Salary'].iloc[0]
print(f'El sueldo de David es: {Sueldo_David}')
# Out:
# El sueldo de David es: 30

# %% [markdown]
# #### Printea todas las líneas en las que el cargo es asociado

# %%
CargosAsociados = employee[employee['Title'] == 'associate']
CargosAsociados
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Printea las 3 primeras filas de tu dataframe
#
# ##### Consejo : Hay 2 maneras de hacerlo. Hazlo de las dos maneras

# %%
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### ¿Encuentra a los empleados cuyo cargo es asociado y cuyo salario es superior a 55?

# %%
emp_filt = employee[(employee['Title'] == 'associate') & (employee['Salary'] > 55)]
emp_filt
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Agrupa a los empleados en función del número de años que llevan trabajando. ¿Cuáles son los salarios medios de cada grupo?

# %%
employee_filt = employee.groupby('Years')['Salary'].mean().reset_index()
employee_filt
# Out:
#    Years     Salary
# 0      1  35.000000
# 1      2  38.333333
# 2      3  55.000000
# 3      4  35.000000
# 4      7  60.000000
# 5      8  70.000000

# %% [markdown]
# #### ¿Cuál es el salario medio por título?

# %%
title_filt = employee.groupby('Title')['Salary'].mean().reset_index()
title_filt
# Out:
#        Title     Salary
# 0         VP  70.000000
# 1    analyst  32.500000
# 2  associate  56.666667

# %% [markdown]
# #### Muestra un resumen visual de los datos utilizando boxplot. ¿Cuáles son los cuartiles primero y tercero? Comenta tus resultados.
#
# * Pista : Cuantiles vs Cuartiles*.
# En Probabilidad y Estadística, los cuantiles son puntos de corte que dividen el rango de una distribución de probabilidad en intervalos continuos con probabilidades iguales. Cuando la división es en cuatro partes, los valores de la variable correspondientes al 25%, 50% y 75% de la distribución total se denominan cuartiles.

# %%
sns.boxplot(x="Salary", data=employee)
plt.show()

# %%
employee.describe()
# Out:
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %%
Q1 = employee['Salary'].quantile(0.25)
Q1
# Out:
# 35.0

# %%
Q3 = employee['Salary'].quantile(0.75)
Q3
# Out:
# 60.0

# %% [markdown]
# #### ¿Es diferente el salario medio por género?

# %%
gender_filt = employee.groupby('Gender')['Salary'].mean().reset_index()
gender_filt
# Out:
#   Gender  Salary
# 0      F    47.5
# 1      M    50.0

# %% [markdown]
# #### Encuentra el mínimo, la media y el máximo de todas las columnas numéricas para cada Departamento.
#
# ##### Sugerencia: Utiliza las funciones de la lección Manipulación de Datos

# %%
summary_stats = employee.groupby('Department')[['Years', 'Salary']].agg(['min', 'mean', 'max']).reset_index()
summary_stats
# Out:
#   Department Years               Salary
#                min      mean max    min   mean max
# 0         HR     2  4.666667   8     30  45.00  70
# 1         IT     1  4.500000   8     30  48.75  70
# 2      Sales     2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Pregunta bonus
#
# #### Para cada departamento, calcule la diferencia entre el salario máximo y el salario mínimo.
#
# ##### * Sugerencia: pruebe a utilizar `agg` o `apply` y `lambda`*.

# %%
# Calcular la diferencia entre el salario máximo y mínimo por departamento
dif = employee.groupby('Department')['Salary'].agg(lambda x: x.max() - x.min()).reset_index()
dif
# Out:
#   Department  Salary
# 0         HR      40
# 1         IT      40
# 2      Sales       0

# %% [markdown]
# # Desafío 3

# %% [markdown]
# #### Abra el conjunto de datos Orders.csv. Nombre el conjunto de datos pedidos

# %%
df_orders = pd.read_csv(r"C:\Users\Flor Guindo\Documents\CURSO DATA ANALYTICS\Orders.csv")
df_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore su conjunto de datos observando los tipos de datos y las estadísticas de resumen. Comenta tus resultados

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %%
df_orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# #### ¿Cuál es el precio medio de compra?

# %%
precio_medio = df_orders['UnitPrice'].mean()
print(f'El precio medio de compra es de {precio_medio:.2f}')
# Out:
# El precio medio de compra es de 3.12

# %% [markdown]
# #### ¿Cuáles fueron los precios de compra más altos y más bajos?

# %%
precio_max = df_orders['UnitPrice'].max()
print(f'El precio máximo de compra es de {precio_max:.2f}')
# Out:
# El precio maximo de compra es de 8142.75

# %%
precio_min = df_orders['UnitPrice'].min()
print(f'El precio minimo de compra es de {precio_min:.2f}')
# Out:
# El precio minimo de compra es de 0.00

# %% [markdown]
# #### Seleccione todos los clientes que tenemos en España

# %%
pedidos_españa = df_orders[df_orders['Country'] == 'Spain']
clientes_pedidos_españa = pedidos_españa['CustomerID'].unique()
clientes_españa = clientes_pedidos_españa.tolist()
print(f'Los clientes que tenemos en españa son: {clientes_españa}')
# Out:
# Los clientes que tenemos en españa son: [12557, 17097, 12540, 12551, 12484, 12539, 12510, 12421, 12502, 12462, 12507, 12541, 12547, 12597, 12545, 12596, 12354, 12417, 12455, 12450, 12548, 12556, 12550, 12546, 12454, 12448, 12544, 12538, 12445, 12442]

# %% [markdown]
# #### ¿Cuántos clientes tenemos en España?
# ##### Pista : Utiliza value_counts()

# %%
pedidos_españa['CustomerID'].value_counts()
# Out:
# CustomerID
# 12540    478
# 12484    346
# 12539    273
# 17097    211
# 12597    206
# 12502    147
# 12556    121
# 12546     69
# 12462     62
# 12354     58
# 12550     57
# 12541     52
# 12545     50
# 12455     48
# 12421     45
# 12510     33
# 12557     33
# 12596     27
# 12417     23
# 12507     22
# 12448     22
# 12538     21
# 12544     19
# 12454     15
# 12442     12
# 12551     10
# 12450      8
# 12547      8
# 12548      5
# 12445      4
# Name: count, dtype: int64

# %%
clientes_unicos = pedidos_españa['CustomerID'].nunique()
clientes_unicos
# Out:
# 30

# %% [markdown]
# #### Selecciona todos los clientes que han comprado más de 50 artículos ?

# %%
clientes = df_orders.groupby('CustomerID')['Quantity'].sum().reset_index()
clientes
compras_mas50 = clientes[clientes['Quantity'] > 50]
compras_mas50
# Out:
#       CustomerID  Quantity
# 0          12346     74215
# 1          12347      2458
# 2          12348      2341
# 3          12349       631
# 4          12350       197
# ...          ...       ...
# 4333       18278        66
# 4335       18281        54
# 4336       18282       103
# 4337       18283      1397
# 4338       18287      1586
#
# [4091 rows x 2 columns]

# %% [markdown]
# #### Selecciona pedidos de España superiores a 50 artículos

# %%
ped_es_sup_50 = pedidos_españa[pedidos_españa['Quantity'] > 50]
ped_es_sup_50
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Seleccionar todos los pedidos gratuitos

# %%
pedidos_gratuitos = df_orders[df_orders['amount_spent'] == 0]
pedidos_gratuitos
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Seleccionar todos los pedidos que sean 'lunch bag
# #### Pista: Utilice las funciones de cadena

# %%
pedidos_lunchbag = df_orders[df_orders['Description'].str.contains('lunch bag', case=False)] 
pedidos_lunchbag
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Seleccione todos los pedidos realizados en 2011 y que sean «lunch bag».

# %%
pedidos_lunchbag2011 = pedidos_lunchbag[pedidos_lunchbag['year'] == 2011]
pedidos_lunchbag2011
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Muestra la distribución de frecuencias del importe gastado en España.

# %%
sns.histplot(pedidos_españa['amount_spent'], bins=100)
plt.title('Distribución de Frecuencias del Importe Gastado en España')
plt.xlabel('Importe Gastado')
plt.ylabel('Frecuencia')
plt.grid()
plt.show()

# %% [markdown]
# #### Seleccione todos los pedidos realizados en el mes de agosto

# %%
pedidos_agosto = df_orders[df_orders['month'] == 8]
pedidos_agosto
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Seleccione cuántos pedidos se realizan por países en el mes de agosto
# ##### Pista: Utilice value_counts()

# %%
pedidos_agosto_por_pais = pedidos_agosto['Country'].value_counts().reset_index()
pedidos_agosto_por_pais.columns = ['Pais', 'Cantidad de pedidos']
pedidos_agosto_por_pais
# Out:
#                Pais  Cantidad de pedidos
# 0    United Kingdom                23105
# 1           Germany                  795
# 2              EIRE                  593
# 3            France                  569
# 4       Netherlands                  280
# 5       Switzerland                  267
# 6             Spain                  252
# 7           Belgium                  194
# 8            Israel                  171
# 9   Channel Islands                  140
# 10        Australia                  107
# 11            Italy                   95
# 12          Austria                   88
# 13           Norway                   77
# 14          Finland                   61
# 15            Malta                   55
# 16         Portugal                   41
# 17           Sweden                   40
# 18      Unspecified                   23
# 19          Iceland                   22
# 20           Poland                   17
# 21          Denmark                   16
# ...

# %% [markdown]
# #### ¿Cuál es el gasto medio por país?

# %%
gasto_medio = df_orders.groupby('Country')['amount_spent'].mean().reset_index()
gasto_medio.columns = ['Pais', 'Gasto medio']
gasto_medio
# Out:
#                     Pais  Gasto medio
# 0              Australia   116.895620
# 1                Austria    25.624824
# 2                Bahrain    32.258824
# 3                Belgium    20.283772
# 4                 Brazil    35.737500
# 5                 Canada    24.280662
# 6        Channel Islands    27.340160
# 7                 Cyprus    22.134169
# 8         Czech Republic    33.069600
# 9                Denmark    49.882474
# 10                  EIRE    36.687745
# 11    European Community    21.670833
# 12               Finland    32.913985
# 13                France    25.056827
# 14               Germany    25.311562
# 15                Greece    32.831172
# 16               Iceland    23.681319
# 17                Israel    29.119718
# 18                 Italy    23.064960
# 19                 Japan   116.561900
# 20               Lebanon    37.641778
# 21             Lithuania    47.458857
# 22                 Malta    24.335625
# 23           Netherlands   120.798282
# ...

# %% [markdown]
# #### ¿Cuál es el artículo más caro?

# %%
art_mascaro = df_orders[df_orders['UnitPrice'] == df_orders['UnitPrice'].max()]
art_mascaro_nombre = art_mascaro[['StockCode', 'Description', 'UnitPrice']]
art_mascaro_nombre
# Out:
#        StockCode Description  UnitPrice
# 118352      POST     postage    8142.75

# %% [markdown]
# #### ¿Cuál fue la cantidad media gastada al año?

# %%
media_gastada_anual = df_orders.groupby('year')['amount_spent'].mean().reset_index()
media_gastada_anual
# Out:
#    year  amount_spent
# 0  2010     21.892733
# 1  2011     22.430074
